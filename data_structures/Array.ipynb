# %%
import array 
import random

# %%
valueList = array.array("f",[10])*100

# %%
len(valueList)
# Out:
# 100
# 100

# %%
for i in range(100):
    valueList[ i ] = random.random()

# %%
# Print the values, one per line.
for value in valueList : print( value )
# Out:
# 0.8653948903083801
# 0.11275388300418854
# 0.3727089464664459
# 0.7879021167755127
# 0.4927569031715393
# 0.15444418787956238
# 0.2312118411064148
# 0.04156922176480293
# 0.7662883996963501
# 0.9911196827888489
# 0.2959116995334625
# 0.42658984661102295
# 0.9988176226615906
# 0.30101561546325684
# 0.9788753986358643
# 0.7389930486679077
# 0.5019457936286926
# 0.2801431715488434
# 0.10861357301473618
# 0.6677150130271912
# 0.9709703326225281
# 0.2969614565372467
# 0.11454992741346359
# 0.31212666630744934
# 0.716620147228241
# 0.40590816736221313
# 0.12881159782409668
# 0.8488321900367737
# 0.47350943088531494
# 0.45122331380844116
# 0.04515385255217552
# 0.9359079003334045
# 0.12321759015321732
# 0.51457679271698
# 0.8158329725265503
# 0.29689884185791016
# 0.23924867808818817
# 0.6360273957252502
# 0.2718104422092438
# 0.4602142572402954
# 0.27022692561149597
# 0.16358062624931335
# 0.2716488242149353
# 0.9821650385856628
# 0.9829164743423462
# 0.5736367106437683
# ...
